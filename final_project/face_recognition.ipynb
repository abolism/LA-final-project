# %% [markdown]
# <div dir="rtl" align="center">
#
# به نام خداوند بخشنده مهربان
#
# <h1>
# پروژه پایانی جبر خطی
# </h1>
#
# حمیدرضا ربیعی، مریم رمضانی
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# نام و نام‌خانوادگی: ابوالفضل اسحاق
#
# شماره دانشجویی: 99101105
#
# </div>

# %% [markdown]
# <div dir="rtl">
#     <h1>
#         چهره‌های ویژه
#     </h1>
# </div>

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     در الگوریتم‌های تشخیص چهره، درون عکس‌ها به دنبال تشخیص خصوصیت‌های خاص عکس بودند. به طور مثال چشم، بینی و ...
#      که می‌توانست حاکی از وجود چهره در عکس باشند. واضح است که چنین روش‌هایی هزینه‌بر و در موارد زیادی نادقیق هستند.
#     <br/>
#     <br/>
#     در این پروژه به دنبال پیاده سازی روشی هستیم که این تشخیص را به گونه‌ای دیگر انجام می‌دهد.
#     در این روش مانند روش قبل به دنبال پیدا کردن مشخصه‌هایی هستیم که یک چهره را تشخیص میدهند ، اما این مشخصه‌ها را با روش دیگری می‌خواهیم پیاده کنیم.
# </div>

# %% [markdown]
# ## Load Data (10 points)

# %% [markdown]
# <br/>
#
# <div dir="rtl" style="font-size:18px">
#     قبل از اینکه درباره پیاده‌سازی این الگوریتم صحبت کنیم لازم است داده‌هایی که مورد استفاده قرار می‌دهیم را داشته باشیم.
#     داده‌های مورد نظر در زیپ مربوطه همراه این نوتبوک قرار گرفته‌است.
#     <br/>
#     دقت کنید که این دیتاست شامل تصاویر مربوط به چهره 200 فرد است.
#     هر کدام از افراد دو عکس یکی حالت طبیعی و یکی خندان دارند.
#     پس در کل 400 عکس داریم.
#     ابتدا تمام عکس‌ها را لود کنید و داشته باشید که در ادامه به آن‌ها نیاز پیدا می‌کنید.
#     <br/>
#     <br/>
#     در نهایت برای این که مطمئن شوید که دیتا را درست لود کرده‌اید،
#     به طور رندوم 5 تا از این چهره‌ها را در دو حالت خندان و عادی نمایش دهید. برای اینکار میتوانید از تابع imshow از لایبرری matplotlib استفاده کنید.
#     <br/>
# </div>

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
img = plt.imread("data/100a.jpg")
plt.imshow(img)
normalImages = []
smilingImages = []
for i in range(200):
    var = i+1
    dircN = "data/{}a.jpg.".format(var)
    dircS = "data/{}b.jpg.".format(var)
    normalImages.append(plt.imread(dircN))
    smilingImages.append(plt.imread(dircS))
# for i in range(100):
# plt.imshow(normalImages[96])
# plt.imshow(smilingImages[96])

# %% [markdown]
# <br/>
# <div dir="rtl" style="font-size:18px">
# حال فعلا تنها با عکس‌های چهره طبیعی کار داریم.
#     190 تا عکس اول از آن را در نظر بگیرید
#      هر کدام را به صورت یک وکتور تک بعدی $\Gamma_i$ در بیاورید.
#      در نهایت ماتریس حاصل از داده‌ها که $\Gamma$ است
#     را تشکیل دهید. دقت کنید که ستون $i$ ام این ماتریس
#     $\Gamma_i$ است.
#     <br/>
# <div/>

# %%
# normalImages[4]
import numpy as np
r = []
for i in range(190):
    ri = normalImages[i]
    ri = np.array(ri)
    r.append(ri.flatten())

r = np.array(r)

r = np.transpose(r)
r
# Out:
# array([[254,  65, 129, ...,  58,  96, 178],
#        [252,  52, 104, ...,  20,  96, 178],
#        [252,  32,  95, ...,  19,  96, 185],
#        ...,
#        [ 65,   0,  53, ...,   1,   3, 100],
#        [ 70,   0,  53, ...,   1,   3, 106],
#        [ 70,   0,  55, ...,   1,   3, 100]], dtype=uint8)

# %% [markdown]
# # PCA
# <br/>
# <br/>
#
# <div dir="rtl" style="font-size:18px">
#  <br/>
#     الگوریتم Principal Component Analysis یا همان PCA یک روش برای کاهش ابعاد داده‌ی موردنظر است که در حوزه یادگیری ماشین و علوم داده کاربرد فراوان دارد.
# با کاهش ابعاد سادگی را افزایش داده و در عین حال همانگونه که انتظار می‌رود ورودی با کاهش دقت همراه خواهد شد. در الگوریتم PCA تلاش بر این است که در عین کاهش ابعاد، کمترین میزان اطلاعات را از دست بدهیم.
#     پیشنهاد می‌شود قبل از انجام پروژه مطالعات بیشتری در رابطه با این الگوریتم داشته باشید.
# <br/>
#     <br/>
# در ادامه‌ی بخش‌ها می‌خواهیم PCA را پیاده سازی کنیم.
# گفتیم که برای تشخیص چهره‌ها به دنبال پیدا کردن مشخصه‌های خاص درون هر عکس هستیم. این مشخصه‌ها ممکن است ترکیبی از چند ویژگی درون عکس باشند، یا حتی ویژگی‌هایی
#     باشند که به طور طبیعی قادر به تشخیص آنها نیستیم.
#     در اینجا با استفاده از الگوریتم PCA در تلاش برای پیدا کردن همچین ویژگی‌هایی هستیم.
#     <br/>
#     <br/>
# با PCA قرار است کار زیر را انجام دهیم :
#     <br/>
#     <br/>
# فرض کنید هر عکس به صورت یک آرایه دو بعدی $N\times M$ باشد ، بنابراین هر عکس را می‌توان با یک بردار به طول $N\times M$ نشان دهیم، پس در یک فضای $N\times M$ بعدی قرار دارد. فرض کنید $W$ فضایی باشد که تمامی عکس‌های صورت در آن قرار دارند ، اسم آن را Face Space بگذارید. در اینجا به دنبال پیدا کردن K بردار عمود بر هم هستیم که فضای $W$ را Span می‌کنند.
#     <div/>

# %% [markdown]
# ## Mean image (5 points)
#
# <div dir="rtl" style="font-size:18px">
#
# <div/>

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     در این قسمت برای نرمالایز کردن نیاز به
#     mean image
#     داریم.
#     آن را بدست آورید و تصویر آن را نمایش هم دهید.
#     $$
#     \Psi = \frac{1}{n}\sum_{i = 1}^{n} \Gamma_i
#     $$
#      در اینجا $n$ تعداد داده های شماست.
#      دقت کنید فعلا کل کار ما بر روی 190 عکس چهره طبیعی است.
# <div/>

# %%
sum = np.zeros((len(r[:, 150]),))
for i in range(190):
    sum += r[:, i]
sum /= 190
y = sum
plt.imshow(y.reshape(normalImages[0].shape))
plt.show(block=True)

# %% [markdown]
# ## Cov Matrix (15 points)
#
# <div dir="rtl" style="font-size:18px">
#
# <div/>

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     در این قسمت باید ماتریس کوواریانس را به صورت زیر تعریف کنید :
#     <br/>
#     $$
#     \Phi_i = \Gamma_i - \Psi
#     $$
#     <br/>
#     $$
#     A = [ \Phi_1 \Phi_2 \dots \Phi_n ]
#     $$
#     <br/>
#     $$
#     C = A A^T
#     $$
#     <br/>
#     حال بردار ویژه های ماتریس $C$ به ترتیب بزرگی مقدار ویژه های متناظرشان ، Principal Components هایی هستند که ما می‌خواهیم.
#     <br/>
#     دقت کنید که ماتریس $C$ ماتریسی $(N \times M)\times (N \times M)$ می‌باشد ، سعی کنید روش بهینه ای برای پیدا کردن بردار ویژه های آن پیاده سازی کنید.
#     به عنوان راهنمایی از
#     $A^T A$
#     کمک بگیرید.
#     <br/>
#     مقدار این مقادیر ویژه را سورت کنید و درون یک نمودار نشان دهید.
#     <br/>
#     بعد از سورت کردن مقدار ویژه‌ها ، بردار ویژه متناظر با 5 مقدار ویژه اول را بکشید.
#     این بردار‌های ویژه را eigen face می‌نامیم.
#     <br/>
#      در نهایت با کمی مطالعه معیاری را انتخاب کنید و تعداد مورد نیاز از Principal Component
#      ها از نظرتان را مشخص نمایید و آن تعداد بردار ویژه را انتخاب کنید.
#      این عدد را K در نظر بگیرید.
#      همچنین ماتریس شامل PCها را U در نظر بگیرید.
#     <br/>
# <div/>

# %%
phi = []
for i in range(len(r[150,:])):
    ri = r[:, i]
    phiI = ri-y
    phi.append(phiI)

phi = np.array(phi)
phi = np.transpose(phi)
phiT = np.transpose(phi)
d = np.dot(phiT,phi)
u, s, vh = np.linalg.svd(d, full_matrices=False)
v = u
sInverse = np.reciprocal(s)
print(sInverse)
sInverse = np.diag(sInverse)
print(sInverse)
u = np.dot(phi,v)
u = np.dot(u,sInverse)
u[abs(u) < 10e-12] = 0
s[abs(s) < 10e-12] = 0
eigenValues = s
eigenValues = np.square(eigenValues)
eigenVectors = []
for i in range(190):
    eigenVectors.append(u[:, i])
eigenVectors = np.array(eigenVectors)
print(eigenValues,eigenVectors)
for i in range(5):
    vector = eigenVectors[i,:]
    plt.imshow(vector.reshape(normalImages[0].shape))
    plt.show(block=True)
# k =10
u = []
for i in range(10):
    u.append(eigenVectors[i,:])
u = np.array(u)
u
# Out:
# [6.64757445e-10 1.38307146e-09 1.59309567e-09 1.67802962e-09
#  2.08700846e-09 2.76657170e-09 3.00274088e-09 3.52888816e-09
#  4.05007012e-09 4.60873008e-09 5.20161187e-09 5.54462376e-09
#  5.81831577e-09 7.22727629e-09 7.82753967e-09 8.11980607e-09
#  8.91613852e-09 1.00023933e-08 1.03476786e-08 1.05407288e-08
#  1.15067372e-08 1.20642515e-08 1.34902853e-08 1.46697308e-08
#  1.54538019e-08 1.62325245e-08 1.66290921e-08 1.73862646e-08
#  1.81191420e-08 1.96353170e-08 2.03578619e-08 2.20708500e-08
#  2.26239479e-08 2.31626971e-08 2.33919954e-08 2.40509626e-08
#  2.47708333e-08 2.63981577e-08 2.67354906e-08 2.81617617e-08
#  2.86854264e-08 2.97454918e-08 3.07504735e-08 3.26539306e-08
#  3.30198271e-08 3.34720146e-08 3.55169085e-08 3.68092310e-08
#  3.86405351e-08 3.93226926e-08 3.99243802e-08 4.04218576e-08
#  4.17859087e-08 4.26570304e-08 4.39904054e-08 4.49308740e-08
#  4.68644158e-08 4.77291132e-08 4.80409568e-08 4.98429245e-08
#  5.13293087e-08 5.32061197e-08 5.39459573e-08 5.52880946e-08
#  5.64575821e-08 5.79597178e-08 6.04886367e-08 6.07793571e-08
#  6.09314480e-08 6.28209113e-08 6.48534326e-08 6.54793941e-08
#  6.70447111e-08 6.87838744e-08 7.13363843e-08 7.28852694e-08
#  7.41655233e-08 7.48347919e-08 7.63007965e-08 7.82480905e-08
#  8.11632524e-08 8.19639887e-08 8.28206312e-08 8.46109232e-08
#  8.68246598e-08 8.71501406e-08 8.81311214e-08 9.07350895e-08
#  9.14371915e-08 9.39942784e-08 9.47936160e-08 9.55814059e-08
#  9.65435538e-08 1.02061501e-07 1.03755842e-07 1.05674731e-07
#  1.07923162e-07 1.08768106e-07 1.10792956e-07 1.13555839e-07
#  1.14913811e-07 1.18500860e-07 1.19407112e-07 1.20165328e-07
#  1.22965656e-07 1.24086078e-07 1.27479285e-07 1.27722726e-07
#  1.29357812e-07 1.30685701e-07 1.34021908e-07 1.36091615e-07
#  1.37967922e-07 1.40276014e-07 1.42032397e-07 1.46710341e-07
#  1.48474940e-07 1.49389610e-07 1.50882766e-07 1.53378857e-07
#  1.56129109e-07 1.58798280e-07 1.60966844e-07 1.63845322e-07
#  1.67982145e-07 1.72186006e-07 1.72642103e-07 1.74394922e-07
#  1.77222043e-07 1.79882808e-07 1.84402828e-07 1.84784924e-07
#  1.88698007e-07 1.89916264e-07 1.94711801e-07 1.97939105e-07
#  1.98320480e-07 2.01329688e-07 2.03551252e-07 2.05252951e-07
#  2.09378670e-07 2.13358256e-07 2.14635345e-07 2.17894163e-07
#  2.23168892e-07 2.26619433e-07 2.31721438e-07 2.36650913e-07
#  2.39298131e-07 2.41122703e-07 2.45591363e-07 2.49014465e-07
#  2.50437178e-07 2.56015028e-07 2.59716533e-07 2.60524091e-07
#  2.67238269e-07 2.70377200e-07 2.72963434e-07 2.73626002e-07
#  2.82680403e-07 2.87827172e-07 2.91318701e-07 2.94754248e-07
#  2.97633172e-07 3.02062174e-07 3.07503978e-07 3.10151593e-07
#  3.10840034e-07 3.20300745e-07 3.23274426e-07 3.34262935e-07
#  3.43450859e-07 3.47443538e-07 3.55662985e-07 3.59355920e-07
#  3.64259134e-07 3.68939886e-07 3.73485629e-07 3.82768904e-07
#  3.92162030e-07 4.03694384e-07 4.11501900e-07 4.18210121e-07
#  4.40975708e-07 4.54181603e-07 4.70683785e-07 4.73492426e-07
#  5.18819930e-07 6.80663572e+07]
# [[6.64757445e-10 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.38307146e-09 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.59309567e-09 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 4.73492426e-07
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   5.18819930e-07 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 6.80663572e+07]]
# [2.26294282e+18 5.22770125e+17 3.94018201e+17 3.55140953e+17
#  2.29589267e+17 1.30652024e+17 1.10908361e+17 8.03016024e+16
#  6.09642052e+16 4.70801083e+16 3.69593321e+16 3.25278858e+16
#  2.95396555e+16 1.91447934e+16 1.63211008e+16 1.51673143e+16
#  1.25790078e+16 9.99521516e+15 9.33929590e+15 9.00033592e+15
#  7.55258482e+15 6.87067225e+15 5.49487389e+15 4.64681854e+15
#  4.18725413e+15 3.79514055e+15 3.61628728e+15 3.30816705e+15
#  3.04596383e+15 2.59372643e+15 2.41287971e+15 2.05287205e+15
#  1.95372402e+15 1.86389629e+15 1.82753398e+15 1.72876147e+15
#  1.62974166e+15 1.43500285e+15 1.39901923e+15 1.26089918e+15
#  1.21528288e+15 1.13020622e+15 1.05753899e+15 9.37840683e+14
#  9.17171202e+14 8.92557688e+14 7.92738020e+14 7.38051235e+14
#  6.69751562e+14 6.46715847e+14 6.27369838e+14 6.12022606e+14
#  5.72717295e+14 5.49564617e+14 5.16754267e+14 4.95347831e+14
#  4.55316706e+14 4.38968412e+14 4.33288041e+14 4.02525101e+14
#  3.79550152e+14 3.53245653e+14 3.43622973e+14 3.27142338e+14
#  3.13729567e+14 2.97678504e+14 2.73308039e+14 2.70699713e+14
#  2.69350014e+14 2.53391204e+14 2.37757412e+14 2.33233374e+14
#  2.22469743e+14 2.11361913e+14 1.96506904e+14 1.88243710e+14
#  1.81800833e+14 1.78563582e+14 1.71767841e+14 1.63324938e+14
#  1.51803266e+14 1.48851711e+14 1.45788386e+14 1.39684151e+14
#  1.32652005e+14 1.31663021e+14 1.28748272e+14 1.21464525e+14
#  1.19606352e+14 1.13187160e+14 1.11286330e+14 1.09459427e+14
#  1.07288565e+14 9.60010757e+13 9.28912665e+13 8.95483727e+13
#  8.58560053e+13 8.45272745e+13 8.14658703e+13 7.75498672e+13
#  7.57278355e+13 7.12126256e+13 7.01357765e+13 6.92534871e+13
#  6.61351489e+13 6.49462202e+13 6.15347959e+13 6.13004470e+13
#  5.97605625e+13 5.85522863e+13 5.56734845e+13 5.39929757e+13
#  5.25343974e+13 5.08198248e+13 4.95707131e+13 4.64599293e+13
#  4.53621553e+13 4.48083771e+13 4.39259060e+13 4.25078370e+13
#  4.10234552e+13 3.96559548e+13 3.85946532e+13 3.72504829e+13
#  3.54383716e+13 3.37290643e+13 3.35510845e+13 3.28800396e+13
#  3.18393741e+13 3.09044260e+13 2.94079564e+13 2.92864634e+13
#  2.80844146e+13 2.77252635e+13 2.63763960e+13 2.55232982e+13
#  2.54252288e+13 2.46708639e+13 2.41352856e+13 2.37367459e+13
#  2.28105168e+13 2.19675232e+13 2.17068857e+13 2.10624460e+13
#  2.00785656e+13 1.94717821e+13 1.86237687e+13 1.78559775e+13
#  1.74631018e+13 1.71998157e+13 1.65795913e+13 1.61268983e+13
#  1.59441877e+13 1.52569977e+13 1.48252084e+13 1.47334422e+13
#  1.40024071e+13 1.36791738e+13 1.34211909e+13 1.33562725e+13
#  1.25143586e+13 1.20708102e+13 1.17832005e+13 1.15101201e+13
#  1.12885285e+13 1.09599182e+13 1.05754419e+13 1.03956576e+13
#  1.03496605e+13 9.74729484e+12 9.56879613e+12 8.95001070e+12
#  8.47755834e+12 8.28383657e+12 7.90537840e+12 7.74373341e+12
#  7.53666304e+12 7.34664039e+12 7.16889484e+12 6.82537791e+12
#  6.50232863e+12 6.13613047e+12 5.90549505e+12 5.71756251e+12
#  5.14245699e+12 4.84775789e+12 4.51379183e+12 4.46040124e+12
#  3.71506741e+12 2.15841516e-16] [[ 6.74030379e-08  8.54310215e-08  7.83463581e-08 ... -1.38801755e-07
#   -1.47967411e-07 -1.57785499e-07]
#  [ 1.41477420e-07  1.26414126e-07  1.17181985e-07 ...  1.26199008e-07
#    1.15205765e-07  9.82828350e-08]
#  [-7.24117090e-07 -7.02617673e-07 -6.85856911e-07 ... -8.35632458e-07
#   -8.34244229e-07 -8.34842166e-07]
#  ...
#  [ 4.95946469e-07  3.57519701e-06  6.37839197e-06 ...  4.81316340e-07
#    3.97918194e-06  1.08173214e-06]
#  [ 1.27738210e-05  1.07050289e-05  8.70468457e-06 ...  1.30813907e-05
#    6.84645443e-06  3.12026730e-06]
#  [ 3.59910221e-05  4.40600853e-05  3.11825070e-06 ... -6.53606957e-06
#   -1.35117626e-05 -2.01870182e-05]]
# array([[ 6.74030379e-08,  8.54310215e-08,  7.83463581e-08, ...,
#         -1.38801755e-07, -1.47967411e-07, -1.57785499e-07],
#        [ 1.41477420e-07,  1.26414126e-07,  1.17181985e-07, ...,
#          1.26199008e-07,  1.15205765e-07,  9.82828350e-08],
#        [-7.24117090e-07, -7.02617673e-07, -6.85856911e-07, ...,
#         -8.35632458e-07, -8.34244229e-07, -8.34842166e-07],
#        ...,
#        [ 5.50829491e-07,  6.49269913e-07,  6.65441521e-07, ...,
#         -4.94021057e-07, -4.56524649e-07, -4.26478784e-07],
#        [ 4.46387262e-08, -3.95564965e-08, -1.17788958e-07, ...,
#          4.68046885e-07,  4.04769627e-07,  3.80746299e-07],
#        [ 4.65103839e-07,  4.82514253e-07,  4.51599787e-07, ...,
#          4.11280598e-08,  5.62323556e-08,  5.29852126e-08]])

# %% [markdown]
# ## Reconstruction images (20 points)

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     در این قسمت قرار است که تابعی بنویسید که عکسی را به همراه
#     Principal Components
#     ‌های مورد نظر بگیرد و آن را دوباره با آن PC‌ها بازسازی کند.
#     برای نحوه‌ی انجام این کار از روابط زیر کمک بگیرید.
#     <br/>
#     $$W = U^T(\Gamma - \Psi)$$
#     $$rec = UW + \Psi$$
#     <br/>
#     دقت کنید که $\Gamma$
#     این‌جا عکس ورودی است.
# <div/>

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#
# <div/>

# %%
def reconstruct_image(orig, pcs):
    """
    A function to reconstruct the original image with the given PCs
    Arguments
    orig - Original image to perform reconstruction on
    pcs  - The principal components to use for the reconstruction

    Returns
    recon - The reconstruction of the orig from pcs
    mse   - The Mean Squared Error of the recon with orig
    """
    # u = []
    # for i in range(len(pcs)):
    #     u.append(eigenVectors[i, :])
    # u = np.array(u)
    u = pcs
    # print(pcs)
    sum = np.zeros((len(pcs[0,:]),))
    # print(len(pcs[0,:]))
    for i in range(len(pcs)):
        sum += pcs[i,:]
    sum /= len(pcs)
    # print(sum,len(sum))
#     y = sum
    # print(y)
    dif = orig-y
    w = np.dot(u,dif)
    rec = np.dot(np.transpose(u),w)
    recon = rec+y

    # sum =0

    sum = 0
    for i in range(len(pcs)):
        x = pcs[i]-y
        x = np.dot(x,x)
        sum += x
    sum /= len(pcs)
    mse = ((recon - orig) ** 2).mean(axis=None)

    # mse = sum
    # todo
    return recon, mse

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     )بخش ب(
#     <br/>
#     حال یکی از عکس‌های دیتاستی که تا الان روی آن کار کردیم )شامل 190 عکس طبیعی( را به صورت رندم انتخاب کنید.
#     برای آن عکس به ازای تمام حالت‌های انتخاب K عملیات بازسازی را انجام دهید.
#     <br/>
#     کمترین و بیشترین MSE را به دست آورید.
#     <br/>
#     MSE را برای Kای که در قسمت قبل انتخاب کردید محاسبه نمایید.
#     <br/>
#     سپس نمودار
#     MSE-number of largest principal components
#     را رسم کنید.
#     <br/>
#     در مرحله‌ی بعد برای یک عکس رندم دیگر از دیتاست، عکس اصلی را همراه عکس‌هایی که از بازسازی با در نظر گرفتن
#     5 انتخاب مختلف برای K که کل محدوده تعداد
#     eigen face‌ها را پوشش دهد،
#     رسم کنید.
#     <br/>
#     نتایج خود را از کار‌هایی که این بخش انجام دادید و از روی خروجی‌های بدست آمده شرح دهید.
# <div/>

# %%
from random import randrange
n = randrange(190)
img = r[:, n]
k=[1,5,50,100,189]
# minMse = np.zeros(len(eigenVectors[0,:]))
# maxMse = np.zeros(len(eigenVectors[:,0]))
# minMse.fill(1000)
minMse = 100000
maxMse = 0
points = []
for i in range(190):
    l = i+1
    u=[]
    for j in range(l):
        u.append(eigenVectors[j, :])
    u = np.array(u)
    # print(i)
    recon , mse =reconstruct_image(img,u)
    points.append((i,mse))
    # print(mse.shape)
    if (mse)<(minMse):
        minMse = mse
    if mse>(maxMse):
        maxMse = mse
    if(i==9):
        print("mse for k=10 is : " , mse)
print(minMse,maxMse)
plt.scatter(*zip(*points))
plt.show()
m = randrange(190)
img = r[:, m]
plt.imshow(img.reshape(normalImages[0].shape))
plt.show(block=True)
for j in k:
    u=[]
    for j in range(l):
        u.append(eigenVectors[j, :])
    u = np.array(u)
    recon , mse = reconstruct_image(img,u)
    img = recon
    plt.imshow(img.reshape(normalImages[0].shape))
    plt.show(block=True)
# Out:
# mse for k=10 is :  1578.6111991193295
# 1578.6111037332685 1578.6112012059275

# %% [markdown]
# ##  Smiling  images (10 points)

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     حال این بار تمام کار‌هایی که در بخش قبل )بخش ب( انجام دادید را تکرار کنید.
#     ولی این بار به جای عکس‌های رندم از چهره‌های عادی، عکس رندم از چهره‌های خندان انتخاب کنید.
#     نتایج خود را از کار‌هایی که این بخش انجام دادید و از روی خروجی‌های بدست آمده شرح دهید.
#     به نظرتان دلایل تفاوت خروجی‌ها در هر قسمت نسبت به قسمت قبل چیست؟
# <div/>

# %%
from random import randrange
n = randrange(190)
rr = []
for i in range(190):
    ri = smilingImages[i]
    ri = np.array(ri)
    rr.append(ri.flatten())
rr = np.array(rr)

rr = np.transpose(rr)
img = rr[:, n]
k=[1,5,50,100,189]
# minMse = np.zeros(len(eigenVectors[0,:]))
# maxMse = np.zeros(len(eigenVectors[:,0]))
# minMse.fill(1000)
minMse = 100000
maxMse = 0
for i in range(190):
    l = i+1
    u=[]
    for j in range(l):
        u.append(eigenVectors[j, :])
    u = np.array(u)
    # print(i)
    recon , mse =reconstruct_image(img,u)
    # print(mse.shape)
    if (mse)<(minMse):
        minMse = mse
    if mse>(maxMse):
        maxMse = mse
    if(i==9):
        print("mse for k=10 is : " , mse)
print(minMse,maxMse)
m = randrange(190)
img = r[:, m]
plt.imshow(img.reshape(normalImages[0].shape))
plt.show(block=True)
for j in k:
    u=[]
    for j in range(l):
        u.append(eigenVectors[j, :])
    u = np.array(u)
    recon , mse = reconstruct_image(img,u)
#     img = recon
    plt.imshow(recon.reshape(normalImages[0].shape))
    plt.show(block=True)
# Out:
# mse for k=10 is :  3666.867165771119
# 3666.8668372965262 3666.8671711364577

# %% [markdown]
# ## Reconstruction of test set (10 points)

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
# تا به اینجای کار ما با محاسبه MSE و بازسازی دوباره  عکس‌ها به  شهودی عددی و بصری از دقت فضای جدید یا همان  face space خود رسیدیم. اما نمی‌توان از این نکته چشم‌پوشی کرد که ارزیابی‌های ما از فضای جدید با استفاده از عکس‌هایی انجام شده که با آنها face space را ساخته‌ایم. در نتیجه این ارزیابی ما به نوعی biased است. برای ارزیابی بهتر MSE را بر روی تعدادی عکس که الگوریتم آنها را تا به حال ندیده است انجام داده و آنها را بازسازی می‌کنیم.
#     <br/>
#     در این قسمت یک عکس از ۱۰ عکس دیده نشده حالت طبیعی را انتخاب نموده و کارهای بخش ب را بر روی آن پیاده کنید. ارزیابی چه تفاوتی کرده است؟ نتیجه‌گیری کنید.
#     <br/>
# <div/>

# %%
from random import randrange
n = randrange(10)
rrr = []
for i in range(10):
    ri = normalImages[i+190]
    ri = np.array(ri)
    rrr.append(ri.flatten())
rrr = np.array(rrr)

rrr = np.transpose(rrr)
img = rrr[:, n]
k=[1,5,50,100,189]
# minMse = np.zeros(len(eigenVectors[0,:]))
# maxMse = np.zeros(len(eigenVectors[:,0]))
# minMse.fill(1000)
# minMse = 100000
# maxMse = 0
# for i in range(190):
#     l = i+1
#     u=[]
#     for j in range(l):
#         u.append(eigenVectors[j, :])
#     u = np.array(u)
#     # print(i)
#     recon , mse =reconstruct_image(img,u)
#     # print(mse.shape)
#     if (mse)<(minMse):
#         minMse = mse
#     if mse>(maxMse):
#         maxMse = mse
#     if(i==9):
#         print("mse for k=10 is : " , mse)
# print(minMse,maxMse)
# m = randrange(190)
# img = r[:, m]
plt.imshow(img.reshape(normalImages[0].shape))
plt.show(block=True)
for j in k:
    u=[]
    for j in range(l):
        u.append(eigenVectors[j, :])
    u = np.array(u)
    recon , mse = reconstruct_image(img,u)
    img = recon
    plt.imshow(img.reshape(normalImages[0].shape))
    plt.show(block=True)

# %%
img1 = plt.imread("data/download1.jpg")
img2 = plt.imread("data/download2.jpg")
img1
plt.imshow(img1)
plt.show(block=True)
plt.imshow(img2)
plt.show(block=True)
u = []
rr = []
# img1 = np.array(img1)
# img1 = img1.flatten()
# for i in range(len(img1)):
#     for j in range(len(img1[0])):
#         img1[i][j] = img1[i][j][0]
# img1 = np.array(img1).reshape((193, 162))
# img1 = np.array(img2)
# img2 = img2.flatten()
# for i in range(len(img2)):
#     for j in range(len(img2[0])):
#         img2[i][j] = img2[i][j][0]
# img2 = img2[0]

print(img1)
img1 = np.array(img1)
print(np.squeeze(img1))
for i in range(193):
    for k in img1[i]:
        k = np.squeeze(k)
print(img1)
# for i in range(190):
#     ri = smilingImages[i]
#     ri = np.array(ri)
#     rr.append(ri.flatten())
# rr = np.array(rr)

# rr = np.transpose(rr)
# img = rr[:, n]
for j in range(190):
    u.append(eigenVectors[j, :])
u = np.array(u)
# recon , mse = reconstruct_image(img1,u)
# img = recon
# plt.imshow(img.reshape(normalImages[0].shape))
# plt.show(block=True)
recon , mse = reconstruct_image(img2,u)
img = recon
plt.imshow(img.reshape(normalImages[0].shape))
plt.show(block=True)
# img1
# img1[0]
# Out:
# [[[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [252 252 252]
#   [253 253 253]
#   [253 253 253]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [252 252 252]
#   [252 252 252]
#   [252 252 252]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [253 253 253]
#   [253 253 253]
#   [253 253 253]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [250 250 250]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# [[[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [252 252 252]
#   [253 253 253]
#   [253 253 253]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [252 252 252]
#   [252 252 252]
#   [252 252 252]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [253 253 253]
#   [253 253 253]
#   [253 253 253]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [250 250 250]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# [[[253 253 253]
#   [253 253 253]
#   [253 253 253]
#   ...
#   [252 252 252]
#   [253 253 253]
#   [253 253 253]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [252 252 252]
#   [252 252 252]
#   [252 252 252]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [253 253 253]
#   [253 253 253]
#   [253 253 253]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [250 250 250]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-a62700cb2a57> in <module>
#      43 # plt.imshow(img.reshape(normalImages[0].shape))
#      44 # plt.show(block=True)
# ---> 45 recon , mse = reconstruct_image(img2,u)
#      46 img = recon
#      47 plt.imshow(img.reshape(normalImages[0].shape))
#
# <ipython-input-35-26498cbaebae> in reconstruct_image(orig, pcs)
#      24 #     y = sum
#      25     # print(y)
# ---> 26     dif = orig-y
#      27     w = np.dot(u,dif)
#      28     rec = np.dot(np.transpose(u),w)
#
# ValueError: operands could not be broadcast together with shapes (193,162,3) (31266,)

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
# دو عکس غیر از چهره انسان و به دلخواه خود )مثل عکس ماشین یا پرنده( را در نظر گرفته.
#     نخست عملیات‌های لازم مثل سیاه سفید کردن یا تغییر سایز را انجام دهید.
#     سپس با استفاده از تمام PCها
#     سعی بر بازسازی آن داشته باشید و MSE را محاسبه نمایید.
#     <br/>
#     آیا الگوریتم به اندازه عکس چهره‌ها موفق عمل کرد؟‌ چرا؟ نتیجه‌گیری کنید.
#     <br/>
# <div/>

# %% [markdown]
# ## Image Rotation (10 points)

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     حال یکی از عکس‌های دیتاستی که تا الان روی آن کار کردیم )شامل 190 عکس طبیعی( را به صورت رندم انتخاب کنید. برای آن عکس تمام rotationهای ممکن
#     )از 0 تا 360( را انجام دهید.
#     حال روی هر یک از عکس‌های بدست آمده با استفاده از تمام PCها عملیات بازسازی و محاسبه‌ی MSE را انجام دهید.
#     <br/>
#     نمودار MSE بر حسب درجه‌ی چرخش را رسم کنید.
#     <br/>
#     برای 10 درجه به صورت یکنواخت بین 360 و 0، عکس اصلی، عکس بعد از دوران، عکس بازسازی‌شده به کمک الگوریتم را رسم کنید.
#     <br/>
#     نتایج به دست آمده را تحلیل کنید. آیا MSE در حالت 360 درجه دوران با حالت 0 برابر است؟
#     چرا؟
#     <br/>
#     <br/>
#     <font color=blue>
#     با استفاده از ndimage میتوانید عکس های خود را بچرخانید.
#         <font/>
#         <br/>
# <div/>

# %%
# ! pip install spicy
import spicy as sp
from scipy import ndimage, misc
points = []
n = randrange(190)
img = r[:, n]
plt.imshow(img.reshape(normalImages[0].shape))
plt.show(block=True)
u = []
for j in range(190):
    u.append(eigenVectors[j, :])
u = np.array(u)
for i in range(360):
    img = normalImages[n]
    j = i+1
    img = ndimage.rotate(img, j, reshape=True)
#     n = randrange(190)
    img = r[:, n]
    recon , mse = reconstruct_image(img,u)
    points.append((i,mse))
plt.scatter(*zip(*points))
plt.show()
j = [6,42,78,114,150,186,222,258,294,330]
for l in j:
    img = normalImages[n]
#     j = i+1
    img = ndimage.rotate(img, l, reshape=True)
    plt.imshow(img)
    plt.show(block=True)

# %% [markdown]
# ## Face Recognition (10 point)

# %% [markdown]
# <div dir="rtl" style="font-size:18px">
#     در این قسمت شما باید Face Recognition را تکمیل کنید. به این معنا که کد شما باید این قابلیت را داشته باشد که پس از اجرای PCA ، تصویر‌ها را پشت سر هم ورودی بگیرد ، و بعد از گرفتن هر تصویر بگوید که آیا این شخص را قبلا دیده است یا نه.
#     <br/>
#     برای اینکار لازم است به این صورت عمل کنید. در ابتدا 10 تا از بهترین پایه های فضا را انتخاب کنید. سپس هر تصویری که به شما داده میشود را میتوانید به صورت یک بردار 10 تایی از ضرایب نشان داد. که برای هر تصویر این ضریب منحصر به فرد میباشد. حال اگر برای 2 بردار 10 تایی خاص ، این ضرایب به اندازه کافی به هم نزدیک باشند میتوانیم بگوییم که تصویر متعلق به یک شخص میباشد.
#     <br/>
# <div/>
